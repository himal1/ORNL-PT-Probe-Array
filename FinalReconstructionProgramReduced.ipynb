# %%
import numpy as np
from pylab import *

# %%
probeloc = np.array([
#[42.3222, 42.3222, -50.9245, 1., 0., 0.],
#[0.0, 59.8526, -50.9245, 1., 0., 0.],
[-42.3222, -42.3222, -50.9245, 1., 0., 0.],
#[-42.3222, 42.3222, -50.9245, 1., 0., 0.],
[59.8526, 0.0, -30.5562, 1., 0., 0.],
#[42.3222, 42.3222, -30.5562, 1., 0., 0.],
[-59.8526, 0.0, -30.5562, 1., 0., 0.],
#[-42.3222, -42.3222, -30.5562, 1., 0., 0.],
[0.0, -59.8526, -30.5562, 1., 0., 0.],
[59.8526, 0.0, 0.0, 1., 0., 0.],
[42.3222, 42.3222, 0.0, 1., 0., 0.],
[-59.8526, 0.0, 0.0, 1., 0., 0.],
[-42.3222, -42.3222, 0.0, 1., 0., 0.],
#[0.0, 59.8526, 0.0, 1., 0., 0.],
#[42.3222, 42.3222, 30.5562, 1., 0., 0.],
[42.3222, -42.3222, 30.5562, 1., 0., 0.],
[-42.3222, -42.3222, 30.5562, 1., 0., 0.],
#[-59.8526, 0.0, 30.5562, 1., 0., 0.],
[0.0, 59.8526, 30.5562, 1., 0., 0.],
#[59.8526, 0.0, 50.9245, 1., 0., 0.],
#[-59.8526, 0.0, 50.9245, 1., 0., 0.],
#[-42.3222, 42.3222, 50.9245, 1., 0., 0.],
#[-42.3222, -42.3222, 50.9245, 1., 0., 0.],
[42.3222, 42.3222, 50.9245, 1., 0., 0.],
#[0.0, -59.8526, -50.9245, 0., 1., 0.],
#[-59.8526, 0.0, -50.9245, 0., 1., 0.],
#[59.8526, 0.0, -50.9245, 0., 1., 0.],
#[42.3222, -42.3222, -30.5562, 0., 1., 0.],
[0.0, 59.8526, -30.5562, 0., 1., 0.],
#[-42.3222, 42.3222, 0.0, 0., 1., 0.],
#[59.8526, 0.0, 30.5562, 0., 1., 0.],
[0.0, -59.8526, 30.5562, 0., 1., 0.],
#[0.0, -59.8526, 50.9245, 0., 1., 0.],
#[0.0, 59.8526, 50.9245, 0., 1., 0.],
#[42.3222, -42.3222, -50.9245, 0., 0., 1.],
#[-42.3222, 42.3222, -30.5562, 0., 0., 1.],
[42.3222, -42.3222, 0.0, 0., 0., 1.],
[-42.3222, 42.3222, 30.5562, 0., 0., 1.],
#[42.3222, -42.3222, 50.9245, 0., 0., 1.]
])

# %%
probeloc = probeloc[:,:3]

# %%
def F_x(x, y, z):
    #Constant terms
    F_x_1 =  0.
    F_x_2 =  -1.
    F_x_3 =  0.
    #First order terms
    F_x_4 =  -1. * x
    F_x_5 =  -3. * z
    F_x_6 =  0.
    F_x_7 =  6. * x
    F_x_8 =  6. * y
    #Second order terms
    #F_x_9 =  -3. * x * z
    #F_x_10 = 4.5 * x * x + 1.5 * y * y - 6. * z * z
    #F_x_11 = 3. * x * y
    #F_x_12 = 30. * x * z
    #F_x_13 = 30. * y * z
    #F_x_14 = -45. * x * x + 45. * y * y
    #F_x_15 = -90. * x * y
    #Third order terms
    #F_x_16 = 1.5 * x * x * x + 1.5 * x * y * y - 6. * x * z * z
    #F_x_17 = 22.5 * x * x * z + 7.5 * y * y * z - 10. * z * z * z
    #F_x_18 = 15. * x * y * z
    #F_x_19 = -30. * x * x * x + 90. * x * z * z
    #F_x_20 = -45. * x * x * y - 15. * y * y * y + 90. * y * z * z
    #F_x_21 = -315. * x * x * z + 315. * y * y * z
    #F_x_22 = -630. * x * y * z
    #F_x_23 = 420. * x * x * x - 1260. * x * y * y
    #F_x_24 = 1260. * x * x * y - 420. * y * y * y

    F_x_col = np.array([F_x_1, 
                        F_x_2, 
                        F_x_3, 
                        F_x_4, 
                        F_x_5, 
                        F_x_6,
                        F_x_7,
                        F_x_8#,
                        #F_x_9,
                        #F_x_10,
                        #F_x_11,
                        #F_x_12,
                        #F_x_13,
                        #F_x_14,
                        #F_x_15,
                        #F_x_16,
                        #F_x_17,
                        #F_x_18,
                        #F_x_19,
                        #F_x_20,
                        #F_x_21,
                        #F_x_22,
                        #F_x_23,
                        #F_x_24
                       ])
    return F_x_col

def F_y(x, y, z):
    #Constant terms
    F_y_1 =  0.
    F_y_2 =  0.
    F_y_3 =  -1.
    #First order terms
    F_y_4 =  -1. * y
    F_y_5 =  0.
    F_y_6 =  -3. * z
    F_y_7 =  -6. * y
    F_y_8 =  6. * x
    #Second order terms
    #F_y_9 =  -3. * y * z
    #F_y_10 = 3. * x * y
    #F_y_11 = 1.5 * x * x + 4.5 * y * y - 6. * z * z
    #F_y_12 = -30. * y * z
    #F_y_13 = 30. * x * z
    #F_y_14 = 90. * x * y
    #F_y_15 = -45. * x * x + 45. * y * y
    #Third order terms
    #F_y_16 = 1.5 * x * x * y + 1.5 * y * y * y - 6. * y * z * z
    #F_y_17 = 15. * x * y * z
    #F_y_18 = 7.5 * x * x * z + 22.5 * y * y * z - 10. * z * z* z
    #F_y_19 = 30. * y * y * y - 90. * y * z * z
    #F_y_20 = -15. * x * x * x - 45. * x * y * y + 90. * x * z * z
    #F_y_21 = 630. * x * y * z
    #F_y_22 = -315. * x * x * z + 315. * y * y * z
    #F_y_23 = -1260. * x * x * y + 420. * y * y * y
    #F_y_24 = 420. * x * x * x - 1260. * x * y * y

    F_y_col = np.array([F_y_1, 
                        F_y_2, 
                        F_y_3, 
                        F_y_4, 
                        F_y_5, 
                        F_y_6,
                        F_y_7,
                        F_y_8#,
                        #F_y_9,
                        #F_y_10,
                        #F_y_11,
                        #F_y_12,
                        #F_y_13,
                        #F_y_14,
                        #F_y_15,
                        #F_y_16,
                        #F_y_17,
                        #F_y_18,
                        #F_y_19,
                        #F_y_20,
                        #F_y_21,
                        #F_y_22,
                        #F_y_23,
                        #F_y_24
                       ])
    return F_y_col

def F_z(x, y, z):
    #Constant terms
    F_z_1 =  1.
    F_z_2 =  0.
    F_z_3 =  0.
    #First order terms
    F_z_4 =  2. * z
    F_z_5 =  -3. * x
    F_z_6 =  -3. * y
    F_z_7 =  0.
    F_z_8 =  0.
    #Second order terms
    #F_z_9 =  -1.5 * x * x - 1.5 * y * y + 3. * z * z
    #F_z_10 = -12. * x * z
    #F_z_11 = -12. * y * z
    #F_z_12 = 15. * x * x - 15. * y * y
    #F_z_13 = 30. * x * y
    #F_z_14 = 0.
    #F_z_15 = 0.
    #Third order terms
    #F_z_16 = -6. * x * x * z - 6. * y * y * z + 4. * z * z * z
    #F_z_17 = 7.5 * x * x * x + 7.5 * x * y * y - 30. * x * z * z
    #F_z_18 = 7.5 * x * x * y + 7.5 * y * y * y - 30. * y * z * z
    #F_z_19 = 90. * x * x * z - 90. * y * y * z
    #F_z_20 = 180.* x * y * z
    #F_z_21 = -105. * x * x * x + 315. * x * y * y
    #F_z_22 = -315. * x * x * y + 105. * y * y * y
    #F_z_23 = 0.
    #F_z_24 = 0.

    F_z_col = np.array([F_z_1, 
                        F_z_2, 
                        F_z_3, 
                        F_z_4, 
                        F_z_5, 
                        F_z_6,
                        F_z_7,
                        F_z_8#,
                        #F_z_10,
                        #F_z_11,
                        #F_z_12,
                        #F_z_13,
                        #F_z_14,
                        #F_z_15,
                        #F_z_16,
                        #F_z_17,
                        #F_z_18,
                        #F_z_19,
                        #F_z_20,
                        #F_z_21,
                        #F_z_22,
                        #F_z_23,
                        #F_z_24
                       ])
    return F_z_col
F = np.vstack((F_x(*probeloc[0]),
               F_x(*probeloc[1]),
               F_x(*probeloc[2]),
               F_x(*probeloc[3]),
               F_x(*probeloc[4]),
               F_x(*probeloc[5]),
               F_x(*probeloc[6]),
               F_x(*probeloc[7]),
               F_x(*probeloc[8]),
               F_x(*probeloc[9]),
               F_x(*probeloc[10]),
               F_x(*probeloc[11]),
               F_y(*probeloc[12]),
               F_y(*probeloc[13]),
               F_z(*probeloc[14]),
               F_z(*probeloc[15])#,
               
               #F_x(*probeloc[16]),
               #F_x(*probeloc[17]),
               #F_x(*probeloc[18]),
               #F_x(*probeloc[19]),
               #F_x(*probeloc[20]),
               #F_x(*probeloc[21]),
               #F_x(*probeloc[22]),
               #F_x(*probeloc[23]),
               #F_y(*probeloc[24]),
               #F_y(*probeloc[25]),
               #F_y(*probeloc[26]),
               #F_y(*probeloc[27]),
               #F_y(*probeloc[28]),
               #F_y(*probeloc[29]),
               #F_y(*probeloc[30]),
               #F_y(*probeloc[31]),
               #F_y(*probeloc[32]),
               #F_y(*probeloc[33]),
               #F_z(*probeloc[34]),
               #F_z(*probeloc[35]),
               #F_z(*probeloc[36]),
               #F_z(*probeloc[37]),
               #F_z(*probeloc[38])
              ))

# %%
data_on = np.loadtxt("C:\\Users\\uky_umit\\Desktop\\bv_switcher_python\\results\\17-04-2023_17-33-42\\bForFR_reduced.dat")
#data_off = np.loadtxt("data/04-10-2022_08-24/after/bv_off.txt")
b = (data_on)
b
# Out:
# array([  7.663,   3.915,   2.23 ,  -3.483,   3.317,   3.375,   2.24 ,
#          0.678,   2.801,   3.257,   6.198,   6.983, -18.978, -22.907,
#         38.341,  35.948])

# %%
#comsol = np.loadtxt("data/comsol_b0/B017fieldprofile_Metgas_noPB_Bx(x).txt", comments='%')
#c_x = np.concatenate((-np.flip(comsol[:,0]),comsol[:,0]))
#c_b = np.concatenate((np.flip(comsol[:,1]),comsol[:,1]))

# %%
a_hat = np.linalg.pinv(F) @ b

# %%
def B_x(x, y, z):
    B_x = np.dot(a_hat, F_x(x, y, z))
    return B_x

def B_y(x, y, z):
    B_y = np.dot(a_hat, F_y(x, y, z))
    return B_y

def B_z(x, y, z):
    B_z = np.dot(a_hat, F_z(x, y, z))
    return B_z

# %%
x_lim = 20
y_lim = 20
z_lim = 20

x = np.linspace(-x_lim, x_lim, 100)
y = np.linspace(-y_lim, y_lim, 100)
z = np.linspace(-z_lim, z_lim, 100)

x_shift = -2.6262626262626263
y_shift = 3.4343434343434325
z_shift = 14.343434343434346

x_shift = 0;
y_shift = 0;
z_shift = 0;

matplotlib.rcParams.update({'font.size': 14})

x_B_x = np.array([B_x(var + x_shift, 0, 0) for var in x])
y_B_x = np.array([B_x(0, var + y_shift, 0) for var in y])
z_B_x = np.array([B_x(0, 0, var + z_shift) for var in z])
x_B_y = np.array([B_y(var + x_shift, 0, 0) for var in x])
y_B_y = np.array([B_y(0, var + y_shift, 0) for var in y])
z_B_y = np.array([B_y(0, 0, var + z_shift) for var in z])
x_B_z = np.array([B_z(var + x_shift, 0, 0) for var in x])
y_B_z = np.array([B_z(0, var + y_shift, 0) for var in y])
z_B_z = np.array([B_z(0, 0, var + z_shift) for var in z])

fig, axs = plt.subplots(3, 3, figsize=(30,18))
axs[0, 0].plot(x, x_B_x)
#axs[0, 0].plot(c_x*100, c_b/4.583)
#axs[0, 0].set_xlim(-20,20)
#axs[0, 0].set_ylim(34,34.3)
axs[0, 1].plot(y, y_B_x)
axs[0, 2].plot(z, z_B_x)
axs[1, 0].plot(x, x_B_y)
axs[1, 1].plot(y, y_B_y)
axs[1, 2].plot(z, z_B_y)
axs[2, 0].plot(x, x_B_z)
axs[2, 1].plot(y, y_B_z)
axs[2, 2].plot(z, z_B_z)

axs[0,0].set(ylabel = 'Bx (mG)');
axs[1,0].set(ylabel = 'By (mG)');
axs[2,0].set(xlabel = 'x (cm)', ylabel = 'Bz (mG)');
axs[2,1].set(xlabel = 'y (cm)');
axs[2,2].set(xlabel = 'z (cm)');

plt.show()
